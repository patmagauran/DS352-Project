# %%
import numpy as np
import pandas as pd

import dask.dataframe as dd
import dask.array as da
import dask.bag as db
import psycopg2

# %%
from dask.distributed import Client
from dask_kubernetes.operator import KubeCluster
cluster = KubeCluster(name='cluster2', image='ghcr.io/patmagauran/mldocker-base:main',env={'EXTRA_CONDA_PACKAGES':'gcsfs'}, resources={"requests": {"memory": "3Gi"}, "limits": {"memory": "6Gi"}}  )
#cluster = KubeCluster.from_name(name="foo")
#cluster.adapt(minimum=4, maximum=8)
cluster.scale(5)
# Scale up: connect to your own cluster with more resources
# see http://dask.pydata.org/en/latest/setup.html

# %%
client = Client(cluster)
client
# Out:
# <Client: 'tcp://10.56.1.2:8786' processes=0 threads=0, memory=0 B>

# %%
df = dd.read_csv("gs://ds352-data/Crash_Incident_Details_CY_1997_-_Current_Annual_County_Transportation.csv", dtype='object')
df._meta.dtypes.to_dict()
# Out:
# {'Crash Record Number': dtype('O'),
#  'County Code': dtype('O'),
#  'County Name': dtype('O'),
#  'Municipality Code': dtype('O'),
#  'Municipality Name': dtype('O'),
#  'District Code': dtype('O'),
#  'District Name': dtype('O'),
#  'Police Agency Code': dtype('O'),
#  'Police Agency Name': dtype('O'),
#  'Crash Year': dtype('O'),
#  'Crash Month': dtype('O'),
#  'Day of Week': dtype('O'),
#  'Time of Day': dtype('O'),
#  'Hour of Day': dtype('O'),
#  'Illumination': dtype('O'),
#  'Weather': dtype('O'),
#  'Road Condition': dtype('O'),
#  'Collision Type': dtype('O'),
#  'Work Zone Type': dtype('O'),
#  'Work Zone Location': dtype('O'),
#  'Intersection Type': dtype('O'),
#  'Traffic Control Device': dtype('O'),
#  'Location Type': dtype('O'),
#  'Urban / Rural': dtype('O'),
#  'Fatality Count': dtype('O'),
#  'Injury Count': dtype('O'),
#  'Person Count': dtype('O'),
#  'Total Unit Count': dtype('O'),
#  'School Bus Indicator': dtype('O'),
#  'School Zone Indicator': dtype('O'),
# ...

# %%
mem1 = df.memory_usage(deep=True).compute()
mem1
# Out:
# 16 Year Old Driver Count     159589958
# 17 Year Old Driver Count     159589958
# 18 Year Old Driver Count     159589958
# 19 Year Old Driver Count     159589958
# 20 Year Old Driver Count     159589958
#                                ...
# Work Zone Moving              88438280
# Work Zone Other               88421588
# Work Zone Shoulder/Median     88500316
# Work Zone Type                89409724
# Workers Present               89093922
# Length: 181, dtype: int64

# %%
df = dd.read_csv("gs://ds352-data/Crash_Incident_Details_CY_1997_-_Current_Annual_County_Transportation.csv",
                 dtype = {'Crash Record Number': 'Int32',
 'County Code': 'category',
 'County Name': 'category',
 'Municipality Code': 'category',
 'Municipality Name': 'category',
 'District Code': 'category',
 'District Name': 'category',
 'Police Agency Code': 'category',
 'Police Agency Name': 'category',
 'Crash Year': 'category',
 'Crash Month': 'Int8',
 'Day of Week': 'Int8',
 'Time of Day': 'string',
 'Hour of Day': 'Int8',
 'Illumination': 'category',
 'Weather': 'category',
 'Road Condition': 'category',
 'Collision Type': 'category',
 'Work Zone Type': 'category',
 'Work Zone Location': 'category',
 'Intersection Type': 'category',
 'Traffic Control Device': 'category',
 'Location Type': 'category',
 'Urban / Rural': 'category',
 'Fatality Count': 'UInt8',
 'Injury Count': 'UInt8',
 'Person Count': 'UInt8',
 'Total Unit Count': 'UInt8',
 'School Bus Indicator': 'category',
 'School Zone Indicator': 'category',
 'Latitude': 'object',
 'Longitude': 'object',
 'Arrival Time': 'Int16',
 'Dispatch Time': 'Int16',
 'Construction Zone Speed Limit': 'Int8',
 'Estimated Hours Closed': 'Int8',
 'Lane Closed': 'category',
 'Lane Closure Direction': 'category',
 'Notify Highway Maintenance': 'category',
 'Special Jurisdiction': 'category',
 'Traffic Control Device Function': 'category',
 'Traffic Detour': 'category',
 'Workers Present': 'category',
 'Work Zone Close/Detour': 'category',
 'Work Zone Flagger': 'category',
 'Work Zone Law Officer': 'category',
 'Work Zone Closure': 'category',
 'Work Zone Moving': 'category',
 'Work Zone Other': 'category',
 'Work Zone Shoulder/Median': 'category',
 'Vehicle Count': 'UInt8',
 'Automobile Count': 'UInt8',
 'Motorcycle Count': 'UInt8',
 'Bus Count': 'UInt8',
 'Small Truck Count': 'UInt8',
 'Heavy Truck Count': 'UInt8',
 'SUV Count': 'UInt8',
 'Van Count': 'UInt8',
 'Bicycle Count': 'UInt8',
 'Suspected Serious Injury Count': 'UInt8',
 'Suspected Minor Injury Count': 'UInt8',
 'Possible Injury Count': 'UInt8',
 'Total Injury Count': 'UInt8',
 'Unknown Injury Degree Count': 'UInt8',
 'Unknown Injury Person Count': 'UInt8',
 '16 Year Old Driver Count': 'UInt8',
 '17 Year Old Driver Count': 'UInt8',
 '18 Year Old Driver Count': 'UInt8',
 '19 Year Old Driver Count': 'UInt8',
 '20 Year Old Driver Count': 'UInt8',
 '50-64 Year Old Driver Count': 'UInt8',
 '65-74 Year Old Driver Count': 'UInt8',
 '75 Plus Year Old Driver Count': 'UInt8',
 'Unbelted Occupant Count': 'UInt8',
 'Unbelted Death Count': 'UInt8',
 'Unbelted Suspected Serious Injury Count': 'UInt8',
 'Belted Death Count': 'UInt8',
 'Belted Suspected Serious Injury Count': 'UInt8',
 'Motorcycle Death Count': 'UInt8',
 'Motorcycle Suspected Serious Injury Count': 'UInt8',
 'Bicycle Death Count': 'UInt8',
 'Bicycle Suspected Serious Injury Count': 'UInt8',
 'Pedestrian Count': 'UInt8',
 'Pedestrian Death Count': 'UInt8',
 'Pedestrian Suspected Serious Injury Count': 'UInt8',
 'Maximum Severity Level': 'UInt8',
 'Commercial Vehicle Count': 'UInt8',
 'Latitude (Decimal)': 'Float32',
 'Longitude (Decimal)': 'Float32',
 'Roadway Surface Type': 'category',
 'Interstate': 'category',
 'State Road': 'category',
 'Local Road Only': 'category',
 'Turnpike': 'category',
 'Wet Road': 'category',
 'Snow Slush Road': 'category',
 'Icy Road': 'category',
 'Sudden Deer': 'category',
 'Shoulder Related': 'category',
 'Rear End': 'category',
 'Head On / Opposite Direction Side Swipe': 'category',
 'Hit Fixed Object': 'category',
 'Single Vehicle Run Off Road': 'category',
 'Work Zone': 'category',
 'Property Damage Only': 'category',
 'Injury or Fatal': 'category',
 'Fatal or Suspected Serious Injury': 'category',
 'Injury': 'category',
 'Fatal': 'category',
 'Non Intersection': 'category',
 'Intersection': 'category',
 'Signalized Intersection': 'category',
 'Stop Controlled Intersection': 'category',
 'Unsignalized Intersection': 'category',
 'School Bus': 'category',
 'School Zone': 'category',
  'Hit Deer': 'category',
 'Hit Tree / Shrub': 'category',
 'Hit Embankment': 'category',
 'Hit Pole': 'category',
 'Hit Guide Rail': 'category',
 'Hit Guide Rail End': 'category',
 'Hit Barrier': 'category',
 'Hit Bridge': 'category',
 'Overturned': 'category',
 'Motorcycle': 'category',
 'Bicycle': 'category',
 'Heavy Truck Related': 'category',
 'Vehicle Failure': 'category',
 'Train / Trolley': 'category',
 'Phantom Vehicle': 'category',
 'Alcohol Related': 'category',
 'Drinking Driver': 'category',
 'Underage Drinking Driver': 'category',
 'Unlicensed': 'category',
 'Distracted': 'category',
 'Cell Phone': 'category',
 'No Clearance': 'category',
 'Running Red Light': 'category',
 'Tailgating': 'category',
 'Cross Median': 'category',
 'Curved Road': 'category',
 'Curve Driver Error': 'category',
 'Limit 65 MPH': 'category',
 'Speeding': 'category',
 'Speeding Related': 'category',
 'Aggressive Driving': 'category',
 'Fatigue / Asleep': 'category',
 'Driver 16 Years Old': 'category',
 'Driver 17 Years Old': 'category',
 'Driver 18 Years Old': 'category',
 'Driver 19 Years Old': 'category',
 'Driver 20 Years Old': 'category',
 'Driver 50 - 64 Years Old': 'category',
 'Driver 65 - 74 Years Old': 'category',
 'Driver 75 Plus': 'category',
 'Unbelted': 'category',
 'Pedestrian': 'category',
 'Commercial Vehicle': 'category',
 'PSP Reported': 'category',
 'NHTSA Aggressive Driving': 'category',
 'Deer Related': 'category',
 'Illumination Dark': 'category',
 'Running Stop Sign': 'category',
 'Train': 'category',
 'Trolley': 'category',
 'Hit Parked Vehicle': 'category',
 'Fire In Vehicle': 'category',
 'Vehicle Towed': 'category',
 'Hazardous Truck': 'category',
 'Suspected Serious Injury': 'category',
 'Suspected Minor Injury': 'category',
 'Possible Injury': 'category',
 'Motorcycle Drinking Driver': 'category',
 'Drug Related': 'category',
 'Illegal Drug Related': 'category',
 'School Bus Unit': 'category',
 'Drugged Driver': 'category',
 'Impaired Driver': 'category',
 'Geographic Location of the Crash': 'object'})
df._meta.dtypes.to_dict()
# Out:
# {'Crash Record Number': Int32Dtype(),
#  'County Code': CategoricalDtype(categories=['__UNKNOWN_CATEGORIES__'], ordered=False),
#  'County Name': CategoricalDtype(categories=['__UNKNOWN_CATEGORIES__'], ordered=False),
#  'Municipality Code': CategoricalDtype(categories=['__UNKNOWN_CATEGORIES__'], ordered=False),
#  'Municipality Name': CategoricalDtype(categories=['__UNKNOWN_CATEGORIES__'], ordered=False),
#  'District Code': CategoricalDtype(categories=['__UNKNOWN_CATEGORIES__'], ordered=False),
#  'District Name': CategoricalDtype(categories=['__UNKNOWN_CATEGORIES__'], ordered=False),
#  'Police Agency Code': CategoricalDtype(categories=['__UNKNOWN_CATEGORIES__'], ordered=False),
#  'Police Agency Name': CategoricalDtype(categories=['__UNKNOWN_CATEGORIES__'], ordered=False),
#  'Crash Year': CategoricalDtype(categories=['__UNKNOWN_CATEGORIES__'], ordered=False),
#  'Crash Month': Int8Dtype(),
#  'Day of Week': Int8Dtype(),
#  'Time of Day': string[python],
# ...

# %%
df.categorize(columns = [ 'County Code',
 'County Name',
 'Municipality Code',
 'Municipality Name',
 'District Code',
 'District Name',
 'Police Agency Code',
 'Police Agency Name',
 'Crash Year',
 'Illumination',
 'Weather',
 'Road Condition',
 'Collision Type',
 'Work Zone Type',
 'Work Zone Location',
 'Intersection Type',
 'Traffic Control Device',
 'Location Type',
 'Urban / Rural',

 'School Bus Indicator',
 'School Zone Indicator',

 'Lane Closed',
 'Lane Closure Direction',
 'Notify Highway Maintenance',
 'Special Jurisdiction',
 'Traffic Control Device Function',
 'Traffic Detour',
 'Workers Present',
 'Work Zone Close/Detour',
 'Work Zone Flagger',
 'Work Zone Law Officer',
 'Work Zone Closure',
 'Work Zone Moving',
 'Work Zone Other',
 'Work Zone Shoulder/Median',

 'Roadway Surface Type',
 'Interstate',
 'State Road',
 'Local Road Only',
 'Turnpike',
 'Wet Road',
 'Snow Slush Road',
 'Icy Road',
 'Sudden Deer',
 'Shoulder Related',
 'Rear End',
 'Head On / Opposite Direction Side Swipe',
 'Hit Fixed Object',
 'Single Vehicle Run Off Road',
 'Work Zone',
 'Property Damage Only',
 'Injury or Fatal',
 'Fatal or Suspected Serious Injury',
 'Injury',
 'Fatal',
 'Non Intersection',
 'Intersection',
 'Signalized Intersection',
 'Stop Controlled Intersection',
 'Unsignalized Intersection',
 'School Bus',
 'School Zone',
  'Hit Deer',
 'Hit Tree / Shrub',
 'Hit Embankment',
 'Hit Pole',
 'Hit Guide Rail',
 'Hit Guide Rail End',
 'Hit Barrier',
 'Hit Bridge',
 'Overturned',
 'Motorcycle',
 'Bicycle',
 'Heavy Truck Related',
 'Vehicle Failure',
 'Train / Trolley',
 'Phantom Vehicle',
 'Alcohol Related',
 'Drinking Driver',
 'Underage Drinking Driver',
 'Unlicensed',
 'Distracted',
 'Cell Phone',
 'No Clearance',
 'Running Red Light',
 'Tailgating',
 'Cross Median',
 'Curved Road',
 'Curve Driver Error',
 'Limit 65 MPH',
 'Speeding',
 'Speeding Related',
 'Aggressive Driving',
 'Fatigue / Asleep',
 'Driver 16 Years Old',
 'Driver 17 Years Old',
 'Driver 18 Years Old',
 'Driver 19 Years Old',
 'Driver 20 Years Old',
 'Driver 50 - 64 Years Old',
 'Driver 65 - 74 Years Old',
 'Driver 75 Plus',
 'Unbelted',
 'Pedestrian',
 'Commercial Vehicle',
 'PSP Reported',
 'NHTSA Aggressive Driving',
 'Deer Related',
 'Illumination Dark',
 'Running Stop Sign',
 'Train',
 'Trolley',
 'Hit Parked Vehicle',
 'Fire In Vehicle',
 'Vehicle Towed',
 'Hazardous Truck',
 'Suspected Serious Injury',
 'Suspected Minor Injury',
 'Possible Injury',
 'Motorcycle Drinking Driver',
 'Drug Related',
 'Illegal Drug Related',
 'School Bus Unit',
 'Drugged Driver',
 'Impaired Driver'])
# Out:
# Dask DataFrame Structure:
# ...

# %%
#Problem columns: Time of day

# %%
mem2 = df.memory_usage(deep=True).compute()
mem2
# Out:
# 16 Year Old Driver Count     5503102
# 17 Year Old Driver Count     5503102
# 18 Year Old Driver Count     5503102
# 19 Year Old Driver Count     5503102
# 20 Year Old Driver Count     5503102
#                               ...
# Work Zone Moving             2759935
# Work Zone Other              2759935
# Work Zone Shoulder/Median    2759871
# Work Zone Type               2760427
# Workers Present              2759339
# Length: 181, dtype: int64

# %%
df = df.dropna()

# %%
import pyarrow as pa
df.to_parquet("gs://ds352-data/rawData",
             schema={
              "Municipality Code": pa.dictionary(pa.uint16(), pa.string(), ordered=False),
                 "Municipality Name": pa.dictionary(pa.uint16(), pa.string(), ordered=False),
                 "District Code": pa.dictionary(pa.uint16(), pa.string(), ordered=False),
                 "District Name": pa.dictionary(pa.uint16(), pa.string(), ordered=False),
                 "Police Agency Code": pa.dictionary(pa.uint16(), pa.string(), ordered=False),
                 "Police Agency Name": pa.dictionary(pa.uint16(), pa.string(), ordered=False)                 
             })

# %%
100 * (mem2.sum() / mem1.sum())
# Out:
# 4.952610904223113

# %%
mem1.sum()
# Out:
# 28308939388

# %%
mem2.sum()
# Out:
# 1402031619
# E1126 23:22:38.318661    9992 portforward.go:406] an error occurred forwarding 63430 -> 8786: error forwarding port 8786 to pod 78bca7fa146e05032c943b395c88a23298e5eeed90754ffd969db89dc951eec5, uid : network namespace for sandbox "78bca7fa146e05032c943b395c88a23298e5eeed90754ffd969db89dc951eec5" is closed
# E1126 23:22:38.319308    9992 portforward.go:234] lost connection to pod
# 2022-11-26 23:23:07,396 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
# E1126 23:24:26.535995   10021 portforward.go:234] lost connection to pod
# 2022-11-26 23:24:49,504 - distributed.deploy.cluster - WARNING - Failed to sync cluster info multiple times - perhaps there's a connection issue? Error:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/distributed/comm/tcp.py", line 498, in connect
#     stream = await self.client.connect(
# ...

# %%
cluster.close()
client.close()
